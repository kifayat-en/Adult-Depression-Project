# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# # Load Data!

# %%
df = pd.read_csv('adult-depression-lghc-indicator-24.csv')

# %%
df.head()
# Out:
#    Year          Strata Strata Name  Frequency  Weighted Frequency  Percent  \
# 0  2012           Total       Total       1920                 NaN    11.74
# 1  2012             Sex        Male        561           1116664.0     8.12
# 2  2012             Sex      Female       1359           2163108.0    15.25
# 3  2012  Race-Ethnicity       White       1314           1806371.0    14.57
# 4  2012  Race-Ethnicity       Black         97            222022.0    13.54
#
#    Lower 95% CL  Upper 95% CL
# 0         11.11         12.37
# 1          7.32          8.92
# 2         14.30         16.20
# 3         13.67         15.46
# 4         10.44         16.65

# %% [markdown]
# 🚀 The shape attribute in pandas tells you the number of rows and columns in a DataFrame.

# %%
df.shape
# Out:
# (161, 8)

# %% [markdown]
# # Check Missing values

# %%
df.isnull().sum()
# Out:
# Year                  0
# Strata                0
# Strata Name           0
# Frequency             0
# Weighted Frequency    7
# Percent               0
# Lower 95% CL          0
# Upper 95% CL          0
# dtype: int64

# %% [markdown]
# 🚀 Fill Misssing Values with mean()
# - The fillna() function in pandas is used to fill missing or NaN (Not a Number) values in a DataFrame or Series with a specified value or method.

# %%
df['Weighted Frequency']  = df['Weighted Frequency'].fillna(df['Weighted Frequency'].mean())

# %%
df.isnull().sum()
# Out:
# Year                  0
# Strata                0
# Strata Name           0
# Frequency             0
# Weighted Frequency    0
# Percent               0
# Lower 95% CL          0
# Upper 95% CL          0
# dtype: int64

# %% [markdown]
# # Check Duplicates Values

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Data Summarize

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 161 entries, 0 to 160
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Year                161 non-null    int64
#  1   Strata              161 non-null    object
#  2   Strata Name         161 non-null    object
#  3   Frequency           161 non-null    int64
#  4   Weighted Frequency  161 non-null    float64
#  5   Percent             161 non-null    float64
#  6   Lower 95% CL        161 non-null    float64
#  7   Upper 95% CL        161 non-null    float64
# dtypes: float64(4), int64(2), object(2)
# memory usage: 10.2+ KB

# %% [markdown]
# # Check Statistical Summary of Numerical Columns

# %% [markdown]
# The describe() function gives statistical summary of numerical columns in a DataFrame.
#
# - Count (number of values)
#
# - Mean (average)
#
# - Standard deviation (std)
#
# - Min (minimum)
#
# - Max (maximum)
#
# - 25%, 50%, 75% (percentiles/quantiles)

# %%
df.describe()
# Out:
#              Year    Frequency  Weighted Frequency     Percent  Lower 95% CL  \
# count   161.00000   161.000000        1.610000e+02  161.000000    161.000000
# mean   2015.00000   429.776398        8.898917e+05   14.789627     11.955280
# std       2.00624   390.297867        6.159810e+05    4.589876      3.705456
# min    2012.00000    28.000000        9.230900e+04    3.970000      2.000000
# 25%    2013.00000   186.000000        4.700770e+05   11.850000      9.650000
# 50%    2015.00000   314.000000        7.496150e+05   14.520000     11.550000
# 75%    2017.00000   511.000000        1.069791e+06   17.190000     14.600000
# max    2018.00000  1964.000000        3.301418e+06   33.090000     24.600000
#
#        Upper 95% CL
# count    161.000000
# mean      17.624224
# std        5.890040
# min        5.340000
# 25%       13.870000
# 50%       16.930000
# 75%       20.050000
# max       44.950000

# %% [markdown]
# # Check Correlation in Numerical Columns

# %%
df.corr()
# Out:
#                         Year  Frequency  Weighted Frequency   Percent  \
# Year                1.000000  -0.003081            0.200619  0.453173
# Frequency          -0.003081   1.000000            0.629439  0.142890
# Weighted Frequency  0.200619   0.629439            1.000000  0.335301
# Percent             0.453173   0.142890            0.335301  1.000000
# Lower 95% CL        0.317585   0.380381            0.533586  0.930467
# Upper 95% CL        0.506528  -0.016719            0.186871  0.973059
#
#                     Lower 95% CL  Upper 95% CL
# Year                    0.317585      0.506528
# Frequency               0.380381     -0.016719
# Weighted Frequency      0.533586      0.186871
# Percent                 0.930467      0.973059
# Lower 95% CL            1.000000      0.820931
# Upper 95% CL            0.820931      1.000000

# %% [markdown]
# # EDA

# %%
df.head()
# Out:
#    Year          Strata Strata Name  Frequency  Weighted Frequency  Percent  \
# 0  2012           Total       Total       1920        8.898917e+05    11.74
# 1  2012             Sex        Male        561        1.116664e+06     8.12
# 2  2012             Sex      Female       1359        2.163108e+06    15.25
# 3  2012  Race-Ethnicity       White       1314        1.806371e+06    14.57
# 4  2012  Race-Ethnicity       Black         97        2.220220e+05    13.54
#
#    Lower 95% CL  Upper 95% CL
# 0         11.11         12.37
# 1          7.32          8.92
# 2         14.30         16.20
# 3         13.67         15.46
# 4         10.44         16.65

# %% [markdown]
# The value_counts() function in pandas is used to count the unique values in a Series or column of a DataFrame.
#
# - It returns a count of how many times each value appears in a column or Series.
#
# - By default, it sorts the counts in descending order.

# %%
print(df['Strata'].value_counts())

plt.figure(figsize=(10,6))
plt.title('Distribution of Strata',fontsize=13)
sns.countplot(x=df['Strata'], palette='Blues')
plt.grid()
plt.show()
# Out:
# Income            42
# Race-Ethnicity    35
# Age               35
# Education         28
# Sex               14
# Total              7
# Name: Strata, dtype: int64

# %%
plt.figure(figsize=(10,6))
plt.title('Depression Rate over The Years',fontsize=14)
sns.lineplot(x=df['Year'], y=df['Percent'])
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.title('Depression Rate over The Gender',fontsize=14)
sns.barplot(data=df[df['Strata']== 'Sex'], x='Strata Name', y='Percent', hue='Year', palette='Reds')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(14,6))
plt.title('Depression Rate over The Income',fontsize=14)
sns.barplot(data=df[df['Strata']== 'Income'], x='Strata Name', y='Percent', hue='Year', palette='viridis')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(14,6))
plt.title('Depression Rate over The Education',fontsize=14)
sns.barplot(data=df[df['Strata']== 'Education'], x='Strata Name', y='Percent', hue='Year', palette='bone')
plt.grid()
plt.xticks(rotation=10)
plt.show()

# %%
plt.figure(figsize=(14,6))
plt.title('Depression Rate over The Race-Ethnicity',fontsize=14)
sns.barplot(data=df[df['Strata']== 'Race-Ethnicity'], x='Strata Name', y='Percent', hue='Year', palette='magma')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(14,6))
plt.title('Depression Rate over The Total',fontsize=14)
sns.barplot(data=df[df['Strata']== 'Total'], x='Strata Name', y='Percent', hue='Year', palette='vlag')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(14,6))
plt.title('Depression Rate over The Age',fontsize=14)
sns.barplot(data=df[df['Strata']== 'Age'], x='Strata Name', y='Percent', hue='Year', palette='BuGn')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.heatmap(df.corr(), annot=True, cmap='Blues')
plt.title('Correlation')
plt.show()

# %% [markdown]
# # Independent and Dependent Variables

# %%
df.drop(columns=['Strata', 'Strata Name'], inplace=True)
X  = df.drop(columns='Percent')
y = df['Percent']

# %% [markdown]
# # Spliting Data into Training and Testing Sets

# %%
X_train,X_test, y_train,y_test = train_test_split(X,y, test_size=0.2)

# %%
print(f"X_train Data: {X_train.shape}")
print(f"y_train Data: {y_train.shape}")
print(f"X_test Data: {X_test.shape}")
print(f"y_test Data: {y_test.shape}")
# Out:
# X_train Data: (128, 5)
# y_train Data: (128,)
# X_test Data: (33, 5)
# y_test Data: (33,)

# %% [markdown]
# # Scale Data

# %%
scaler =  StandardScaler()
scaler.fit(X_train, X_test)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# # Models Building

# %% [markdown]
# 🚀 Linear Regression

# %%
lr = LinearRegression()
lr.fit(X_train_scaled,y_train)
y_pred1 = lr.predict(X_test_scaled)

print("R2 Score: ", r2_score(y_test, y_pred1))
print("Mean_Squared_Error: ", mean_squared_error(y_test,y_pred1))
# Out:
# R2 Score:  0.9999991770399986
# Mean_Squared_Error:  1.2246730915776628e-05

# %% [markdown]
# 🚀 Ridge Regression

# %%
ridge =  Ridge()
ridge.fit(X_train_scaled,y_train)
y_pred2 = ridge.predict(X_test_scaled)

print("R2 Score: ", r2_score(y_test,y_pred2))
print("Mean_Squared_Error: ", mean_squared_error(y_test,y_pred2))
# Out:
# R2 Score:  0.999923292622451
# Mean_Squared_Error:  0.0011415070119444478

# %% [markdown]
# 🚀 Lasso Regression

# %%
lasso =  Lasso()
lasso.fit(X_train_scaled,y_train)
y_pred3 = lasso.predict(X_test_scaled)

print("R2 Score: ", r2_score(y_test,y_pred3))
print("Mean_Squared_Error: ", mean_squared_error(y_test,y_pred3))
# Out:
# R2 Score:  0.9524773213809735
# Mean_Squared_Error:  0.7072001755680205

# %% [markdown]
# 🚀 Random Forest Regressor

# %%
rf =  RandomForestRegressor(n_estimators=500)
rf.fit(X_train_scaled,y_train)
y_pred4 = rf.predict(X_test_scaled)

print("R2 Score: ", r2_score(y_test,y_pred4))
print("Mean_Squared_Error: ", mean_squared_error(y_test,y_pred4))
# Out:
# R2 Score:  0.9899615219104972
# Mean_Squared_Error:  0.14938580218181927

# %% [markdown]
# 🚀 Decision Tree Regressor

# %%
tree =  DecisionTreeRegressor()
tree.fit(X_train,y_train)
y_pred5 = tree.predict(X_test)

print("R2 Score: ", r2_score(y_test,y_pred5))
print("Mean_Squared_Error: ", mean_squared_error(y_test,y_pred5))
# Out:
# R2 Score:  0.9508765872414773
# Mean_Squared_Error:  0.7310212121212126

# %%
plt.figure(figsize=(14, 7))
plt.plot(y_test.values, label='Actual Values', marker='o', color='green')
plt.plot(y_pred1, label='Linear R Predicted Values', color='black', linestyle='--')
plt.plot(y_pred2, label='Ridge R Predicted Values', color='blue', linestyle='--')
plt.plot(y_pred3, label='Lasso R Predicted Values', color='purple', linestyle='--')
plt.plot(y_pred4, label='Random F Predicted Values', color='pink', linestyle='--')
plt.plot(y_pred5, label='Decision T Predicted Values', color='brown', linestyle='--')



plt.title('Model Predictions',fontsize=14)
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Summary

# %% [markdown]
# ✅ Analysis of the Graph:  Model Predictions vs Actual Values.
# The green dots represent the Actual Values.
#
# The dashed lines represent different models:
#
# - Black – Linear Regression
#
# - Blue – Ridge Regression
#
# - Purple – Lasso Regression
#
# - Pink – Random Forest
#
# - Brown – Decision Tree

# %% [markdown]
# ✅ Which Model Performed Best?
# From the plot, it seems that the Ridge Regression (Blue Line) closely follows the actual values in most areas,
# even better than Linear Regression in terms of general accuracy and stability.

# %% [markdown]
# ✨ Best Model: Ridge Regression.
# Yes, based on the visual performance, Ridge Regression appears to be the best model among all. It manages a good balance between:
#
# - Fitting the data well (low bias),
#
# - Avoiding extreme spikes (low variance),
#
# - And tracking the actual values without much deviation.
#
# - So, if you used Ridge Regression, then you made a great choice!

# %% [markdown]
# Thanks! Please Upvoted.
